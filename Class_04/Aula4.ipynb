# %% [markdown]
# # Aula 4 - Visualizando Dados

# %% [markdown]
# Até agora no nosso curso, vimos como carregar arquivos de dados, analisá-los e também como arrumar informações erradas ou faltantes de datasets. Mas ainda não fizemos nada muito interessante e visível com os dados que mexemos. 😔\
# Então é exatamente isso que faremos na aula de hoje: criaremos **gráficos** baseados nos datasets, processo popularmente conhecido como *plotar* gráficos.

# %% [markdown]
# Como todos já devem saber, gráficos são uma forma muito útil de passar muitas informações de forma rápida, concisa simples. Consequentemente, a habilidade do cientista de dados de criar gráficos que façam sentido e expliquem bem os dados que estão sendo mostrados, podem fazer milagres na hora de apresentar as conclusões de uma análise.

# %% [markdown]
# Mas sem mais delongas, vamos aprender a criar nossos gráficos!

# %% [markdown]
# ## Bibliotecas

# %% [markdown]
# Primeiramente, como fazemos no início de todas as aulas, precisamos importar nossas bibliotecas. Existem algumas diferentes bibliotecas para *plotagem* de gráficos. As mais comuns são a matplotlib e a seaborn. A própria biblioteca pandas também tem um método para geração de gráfico, mas nesta aula, vamos usar o matplotlib.\
# Então, nesta aula usaremos as seguintes três bibliotecas:
# * Numpy
# * Pandas
# * matplotlib.pyplot

# %% [markdown]
# Vamos importar elas logo de cara pra não dar problema depois:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# É bom sempre lembrar que se você tiver alguma dúvida ou não sabe como executar algo, você pode procurar respostas nas documentações oficiais. Você pode acessar as documentações nos links abaixo:
# * [Documentação do NumPy](https://numpy.org/doc/)
# * [Documentação do Pandas](https://pandas.pydata.org/docs/user_guide/index.html)
# * [Documentação do Matplotlib](https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html)
#
# As documentações podem parecer um pouco complicadas demais no início, mas conforme você se familiariza com a biblioteca, você vai conseguir navegar mais facilmente por elas. Na dúvida, você sempre pode se redirecionar ao abençoado Google. 🙏

# %% [markdown]
# ## Plots Iniciais: Gráfico de Linhas 📈

# %% [markdown]
# Enfim, bora plotar uns gráficos!

# %% [markdown]
# Vamos começar com um exemplo simples. Para fazer qualquer gráfico, usamos o método `.plot` da nossa biblioteca.

# %%
plt.plot([1,2,3],[2,4,6])

plt.show()

# %% [markdown]
# Vamos entender o que aconteceu ali em cima.\
# Dentro da nossa função `plot`, colocamos duas listas, a `[1,2,3]` e a `[2,4,6]`. A primeira lista que colocamos, se refere aos valores de $x$ no gráfico, enquanto a segunda representa os valores de $y$. Temos como resultado, um conjunto de pontos: (1,2), (2,4) e (3,6). A própria biblioteca vai se encarregar de ligar todos os pontos que criamos, fazendo a linha que mostramos acima.

# %% [markdown]
# ### **🚨 Cuidado! 🚨**
# Quando criamos gráficos em notebooks, nossos plots são resetados em cada nova célula. Então, para *plotagens* mais complexas, precisamos colocar nossos códigos tudo em uma mesma célula!! Criamos nosso gráfico usando o método `plot()` e mostramos ele com o `show()`. Se tentarmos usar o `show()` em uma célula nova, nada vai acontecer:

# %%
plt.show()

# %% [markdown]
# Antes de tentarmos fazer gráficos muito complexos, vamos aprender o básico pra alterarmos a aparência dos nossos gráficos.

# %% [markdown]
# ### Título

# %% [markdown]
# Podemos adicionar um título pro nosso gráfico com o método `title()`:

# %%
plt.plot([1,2,3],[2,4,6])

plt.title('nosso gráfico')

plt.show()

# %% [markdown]
# ### Nomeação de Eixos

# %% [markdown]
# Podemos colocar nomes nos eixos $x$ e $y$ com os métodos `xlabel()` e `ylabel()`, respectivamente:

# %%
plt.plot([1,2,3], [2,4,6])

plt.title('nosso gráfico!!!')

plt.xlabel('eixo X')

plt.ylabel('eixo Y')

plt.show()

# %% [markdown]
# Vamos tentar plotar dois gráficos juntos? O jeito mais fácil de fazer isso é chamando o `.plot` duas vezes.

# %%
x1 = [1,2,3,4,5]
y1 = [2,4,6,8,10]

x2 = [0,2,4,8,16]
y2 = [4,4,4,4,4]

plt.plot(x1,y1)
plt.plot(x2,y2)

plt.title('gráfico DUPLO')

plt.xlabel('eixo X')

plt.ylabel('eixo Y')

plt.show()

# %% [markdown]
# Beleza! Plotamos dois gráficos juntos. Mas tá meio feia a nossa imagem de retorno, não acha? Vamos tentar mudar isso.\
# Usando o método `.figure()`, podemos alterar as configurações da imagem do gráfico que o matplot nos retorna. Dentre os parâmetros que podemos colocar dentro do `.figure()`, temos o *figsize* e o *dpi*. O *figsize* é usado pra escolhermos as proporções da nossa imagem. Colocando $(3,4)$ para o *figsize*, por exemplo, o gráfico vai retornar com uma proporção 3x4.\
# Já o *dpi* serve para realmente mudarmos o tamanho do nosso gráfico. *dpi* indica o número de pontos por polegada (*dots per inch*). Então, quanto maior o número que colocarmos, maior será o gráfico.\
# Enfim, bora deixar nosso gráfico maior! Vamos colocar a proporção 5x3 e o *dpi* em 150:

# %%
plt.figure(figsize=(5,3), dpi=150)

plt.plot(x1,y1)
plt.plot(x2,y2)

plt.title('gráfico DUPLO')

plt.xlabel('eixo X')

plt.ylabel('eixo Y')

plt.show()

# %% [markdown]
# Beleza! Demos uma mudada e agora o nosso gráfico já tá mais bonitinho. Mas vamos tentar mudar mais algumas coisas.

# %% [markdown]
# ### Cor das Linhas

# %% [markdown]
# Podemos escolher a cor de cada linha do nosso gráfico passando o parâmetro `color` dentro do ``plot``.

# %%
plt.figure(figsize=(5,3), dpi=150)

plt.plot((np.random.randn(1000).cumsum()), color="blue")
plt.plot((np.random.randn(1000).cumsum()), color="magenta")

plt.title('gráfico DUPLO')

plt.xlabel('eixo X')

plt.ylabel('eixo Y')

plt.show()

# %% [markdown]
# Podemos passar cores pelos seus códigos HEX também.

# %%
plt.figure(figsize=(5,3), dpi=150)

plt.plot((np.random.randn(1000).cumsum()), color="#ae93f9")
plt.plot((np.random.randn(1000).cumsum()), color="#48f07b")

plt.title('gráfico DUPLO')

plt.xlabel('eixo X')

plt.ylabel('eixo Y')

plt.show()

# %% [markdown]
# Pra ficar mais legal, ao invés de plotar aquelas linhas que fizemos lá em cima, coloquei a função `randn` da biblioteca numpy pra gerar 1000 números aleatórios pra gente, junto com o método `cumsum`, que nos retorna a soma cumulativa dos elementos.

# %% [markdown]
# ### Estilo da Linha

# %% [markdown]
# Podemos mudar o estilo da nossa linha usando o parâmetro `linestyle` dentro do `plot`. Temos as seguintes opções pra este parâmetro: '-' que nos desenhará a linha sólida, '--' que fará a linha traçada, '-.' fará a linha com pontos e ':' só fara os pontos. Vamos ver todos juntos?

# %%
plt.figure(figsize=(5,4), dpi=150)

plt.plot((np.random.randn(30).cumsum()), color="#ae93f9", linestyle='-')
plt.plot((np.random.randn(30).cumsum()), color="#48f07b", linestyle='--')
plt.plot((np.random.randn(30).cumsum()), color="#e7f07e", linestyle='-.')
plt.plot((np.random.randn(30).cumsum()), color="#ff79c6", linestyle=':')

plt.title('gráfico QUÁDRUPLO')

plt.xlabel('eixo X')

plt.ylabel('eixo Y')

plt.show()

# %% [markdown]
# ### Marcadores

# %% [markdown]
# Ainda, podemos colocar marcadores nos nossos gráficos com o parâmetro `marker`. Existem dezenas de possíveis valores que podemos colocar, você pode ver a lista [aqui](https://matplotlib.org/3.5.3/api/markers_api.html#module-matplotlib.markers). Neste notebook, vou mostrar os mais comuns:
# * '.' vai colocar pontos;
# * 'o' vai colocar bolinhas;
# * '^' adiciona um triângulo pra cima;
# * '*' adiciona uma estrela

# %%
plt.figure(figsize=(5,4), dpi=150)

plt.plot((np.random.randn(30).cumsum()), color="#ae93f9", linestyle='-', marker='.')
plt.plot((np.random.randn(30).cumsum()), color="#48f07b", linestyle='--', marker='o')
plt.plot((np.random.randn(30).cumsum()), color="#e7f07e", linestyle='-.', marker='^')
plt.plot((np.random.randn(30).cumsum()), color="#ff79c6", linestyle=':', marker='*')

plt.title('gráfico QUÁDRUPLO')

plt.xlabel('eixo X')

plt.ylabel('eixo Y')

plt.show()

# %% [markdown]
# Ficou meio estranho, não? Podemos mudar o tamanho dos marcadores com outro parâmetro: o `markersize`.

# %%
plt.figure(figsize=(5,4), dpi=150)

plt.plot((np.random.randn(30).cumsum()), color="#ae93f9", linestyle='-', marker='.', markersize=6)
plt.plot((np.random.randn(30).cumsum()), color="#48f07b", linestyle='--', marker='o', markersize=5)
plt.plot((np.random.randn(30).cumsum()), color="#e7f07e", linestyle='-.', marker='^', markersize=5)
plt.plot((np.random.randn(30).cumsum()), color="#ff79c6", linestyle=':', marker='*', markersize=5)

plt.title('gráfico QUÁDRUPLO')

plt.xlabel('eixo X')

plt.ylabel('eixo Y')

plt.show()

# %% [markdown]
# ### Legendas

# %% [markdown]
# Colocar legendas em nossos gráficos é outro elemento essencial pra uma boa leitura. Podemos colocar uma legenda com o método `legend()`. Pra que ele adicione as legendas corretamente, colocamos o parâmetro `label` dentro de cada `plot` que fizemos, com o nome da linha.

# %%
plt.figure(figsize=(5,4), dpi=150)

plt.plot((np.random.randn(30).cumsum()), color="#ae93f9", linestyle='-', marker='.', markersize=6, label='roxo')
plt.plot((np.random.randn(30).cumsum()), color="#48f07b", linestyle='--', marker='o', markersize=5, label='verde')
plt.plot((np.random.randn(30).cumsum()), color="#e7f07e", linestyle='-.', marker='^', markersize=5, label='amarelo')
plt.plot((np.random.randn(30).cumsum()), color="#ff79c6", linestyle=':', marker='*', markersize=5, label='rosa')

plt.title('gráfico QUÁDRUPLO')

plt.xlabel('eixo X')

plt.ylabel('eixo Y')

plt.legend()

plt.show()

# %% [markdown]
# ### Grid

# %% [markdown]
# Às vezes fica muito difícil ver os valores só jogados ali dentro do gráfico. Algo que ajuda muito na leitura é a grade. Podemos adicionar uma grade com o método `grid()`.

# %%
plt.figure(figsize=(6,4), dpi=150)

plt.plot((np.random.randn(30).cumsum()), color="#ae93f9", linestyle='-', marker='.', markersize=6, label='roxo')
plt.plot((np.random.randn(30).cumsum()), color="#48f07b", linestyle='--', marker='o', markersize=5, label='verde')
plt.plot((np.random.randn(30).cumsum()), color="#e7f07e", linestyle='-.', marker='^', markersize=5, label='amarelo')
plt.plot((np.random.randn(30).cumsum()), color="#ff79c6", linestyle=':', marker='*', markersize=5, label='rosa')

plt.title('gráfico QUÁDRUPLO')

plt.xlabel('eixo X')

plt.ylabel('eixo Y')

plt.legend()

plt.grid()

plt.show()

# %% [markdown]
# Podemos escolher o eixo da grid colocando os parâmetros `axis='x'` ou `axis='y'`, pra mostrar a grid vertical ou horizontal respectivamente.

# %%
plt.figure(figsize=(6,4), dpi=150)

plt.plot((np.random.randn(30).cumsum()), color="#ae93f9", linestyle='-', marker='.', markersize=6, label='roxo')
plt.plot((np.random.randn(30).cumsum()), color="#48f07b", linestyle='--', marker='o', markersize=5, label='verde')
plt.plot((np.random.randn(30).cumsum()), color="#e7f07e", linestyle='-.', marker='^', markersize=5, label='amarelo')
plt.plot((np.random.randn(30).cumsum()), color="#ff79c6", linestyle=':', marker='*', markersize=5, label='rosa')

plt.title('gráfico QUÁDRUPLO')

plt.xlabel('eixo X')

plt.ylabel('eixo Y')

plt.legend()

plt.grid(axis='y')

plt.show()

# %% [markdown]
# Pronto! Agora que sabemos deixar nossos gráficos bonitos, vamos tentar fazer gráficos usando nossos datasets!

# %% [markdown]
# Vamos ver se conseguimos extrair algumas informações legais do dataset da população mundial que vimos nas últimas aulas!

# %%
wrld_pop = pd.read_csv('world_population.csv')
wrld_pop = wrld_pop.set_index('CCA3')
wrld_pop.head()
# Out:
#       Rank Country/Territory           Capital      Continent  \
# CCA3
# CHN      1             China           Beijing           Asia
# IND      2             India         New Delhi           Asia
# USA      3     United States  Washington, D.C.  North America
# IDN      4         Indonesia           Jakarta           Asia
# PAK      5          Pakistan         Islamabad           Asia
#
#       2022 Population  2020 Population  2015 Population  2010 Population  \
# CCA3
# CHN        1425887337       1424929781       1393715448       1348191368
# IND        1417173173       1396387127       1322866505       1240613620
# USA         338289857        335942003        324607776        311182845
# IDN         275501339        271857970        259091970        244016173
# PAK         235824862        227196741        210969298        194454498
#
#       2000 Population  1990 Population  1980 Population  1970 Population  \
# CCA3
# ...

# %% [markdown]
# ## Tipos de Gráficos

# %% [markdown]
# Como todos devem saber, existem diversos tipos de gráficos, gráficos de setores (popularmente conhecido como gráfico de pizzas), linha, barras, etc. Vamos tentar explorar um pouco dos mais usados.

# %% [markdown]
# ### Gráficos de Pizza 🍕

# %% [markdown]
# Vamos tentar responder algumas perguntas usando nosso dataset. Qual é a porcentagem total de população que cada continente representa?

# %% [markdown]
# Esta é uma pergunta que pode ser resolvida a partir de um gráfico de pizza. O gráfico do tipo pizza é um dos gráficos mais fáceis e simples de se entender e aplicar.

# %% [markdown]
# Então bora fazer um gráfico do tipo Pizza que mostra a porcentagem da população de 2022 separado por continente.

# %% [markdown]
# A gente pode começar criando um novo dataframe que agrupa os países pelo continente. Temos uma função própria do pandas que faz exatamente isso! 😱 Essa função é a `groupby()`.

# %% [markdown]
# #### **groupby()**

# %% [markdown]
# O método `groupby()` serve para agruparmos dois datasets em um.\
# Colocando o nome da coluna que queremos agrupar, vamos obter um novo dataframe em que o índice é a coluna que escolhemos. Precisamos informar ao pandas o que queremos fazer com as outras colunas também. Fazemos isso colocando um segundo método depois do ``groupby()``. Neste caso, queremos somar a população de todos os países de cada continente. Então, usamos o método `sum()`.

# %%
continentes = wrld_pop.groupby('Continent').sum()
continentes
# Out:
# /tmp/ipykernel_6694/1163185434.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   continentes = wrld_pop.groupby('Continent').sum()
#                Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         5253       1426730932       1360671810       1201102442
# Asia           3878       4721383274       4663086535       4458250182
# Europe         6225        743147538        745792196        741535608
# North America  6437        600296136        594236593        570383850
# Oceania        4336         45038554         43933426         40403283
# South America  1366        436816608        431530043        413134396
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# ...

# %% [markdown]
# Veja que lindo nosso novo dataframe! Perceba que agora temos um novo dataset que agrupou todos os países pelos seus continentes e somou todos os valores de dentro das colunas. Alguns dados somados ali dentro não fazem sentido, então podemos retirá-los.

# %%
continentes.drop(['Rank', 'Density (per km²)', 'Growth Rate'], axis=1, inplace=True)
continentes
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Africa              1426730932       1360671810       1201102442
# Asia                4721383274       4663086535       4458250182
# Europe               743147538        745792196        741535608
# North America        600296136        594236593        570383850
# Oceania               45038554         43933426         40403283
# South America        436816608        431530043        413134396
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa              1055228072        818946032        638150629
# Asia                4220041327       3735089604       3210563577
# Europe               735613934        726093423        720320797
# North America        542720651        486069584        421266425
# Oceania               37102764         31222778         26743822
# South America        393078250        349634282        297146415
#
# ...

# %% [markdown]
# Pronto! Agora nosso dataframe só tem informações úteis! 😎

# %% [markdown]
# Podemos criar um gráfico de pizza com o método `.pie()`. A própria biblioteca matplotlib vai se encarregar de calcular o tamanho do nosso setor. Então podemos colocar números brutos no método e ele vai calcular quanto que cada elemento representa do valor total. Ficou difícil de entender ? Vamos ver o `.pie()` trabalhando. 😌

# %% [markdown]
# Dentro do `pie()`, a gente coloca a coluna do nosso dataframe que queremos que seja contada. Para colocarmos as legendas, adicionamos o parâmetro `labels` e colocamos os nomes que representam cada número. Nesse caso, como o nome dos continentes é o índice do nosso dataframe, colocamos continentes.index como valor do parâmetro.

# %% [markdown]
# Por fim, podemos colocar o parâmetro `autopct` pra que possamos escolher como nossa porcentagem aparece. Nesse caso, vou usar `'%.2f%%'`. O primeiro % é para indicar que os próximos caracteres serão um valor. O .2f pede que o número seja representado como um float com 2 dígitos depois da vírgula. Por fim, o %% serve para mostrar o sinal de porcentagem depois do número. Sim, precisamos colocar o dois sinais (%%) ao invés de 1, senão o Python interpreta que deveria ter algum número ali 😑.

# %%
plt.figure(figsize=(5,4), dpi=150)
plt.pie(continentes['2022 Population'], labels=continentes.index, autopct='%.2f%%')
plt.show()

# %% [markdown]
# Perceba que colocamos a coluna 2022 Population ali no `.pie()` e ele nos retornou a porcentagem certinha de cada país! 😮\
# Nós passamos um valor inteiro e a biblioteca se deu o trabalho de somar e encontrar a fração que cada continente representa no total da população. Legal né? 😝

# %% [markdown]
# O nosso dataset inclusive tem esse dado de percentual. Podemos verificar como o cálculo tá certo usando aqueles valores:

# %%
continentes['World Population Percentage']
# Out:
# Continent
# Africa           17.87
# Asia             59.19
# Europe            9.33
# North America     7.51
# Oceania           0.55
# South America     5.48
# Name: World Population Percentage, dtype: float64

# %% [markdown]
# Olha como os valores ficaram parecidos! 🤭

# %% [markdown]
# #### **Exercício**
# Agora é a sua vez! Tente fazer um gráfico de pizza que mostre a porcentagem da Área que cada continente representa! Dica: você pode usar o nosso dataframe continentes ali de cima. 🧐

# %%
# Coloque seu código aqui
plt.figure(figsize=(5,4), dpi=150)
plt.pie(continentes['Area (km²)'], labels=continentes.index, autopct='%.2f%%')
plt.show()

# %% [markdown]
# ### Gráficos de Barras 📊

# %% [markdown]
# Podemos criar gráficos de barra usando o método `bar()`. Colocamos como parâmetros o eixo $x$ e $y$, respectivamente.

# %% [markdown]
# Se tentarmos mostrar a população de cada continente no modo de barras, colocamos o índice do nosso dataframe continentes como eixo $x$ e a população em 2022 no eixo $y$:

# %%
plt.figure(figsize=(8,3), dpi=150)
plt.bar(continentes.index, continentes['2022 Population'])
plt.ylabel('População em Bilhões')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Bah, mas a grid tá na frente das barras... isso tá muito estranho. Podemos mudar isso passando o parâmetro `zorder` no método `bar` pra colocar a coordenada Z dele acima do grid. Um valor de 2 para o `zorder` será o suficiente:

# %%
plt.figure(figsize=(8,3), dpi=150)
plt.bar(continentes.index, continentes['2022 Population'], zorder=2)
plt.ylabel('População em Bilhões')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# O método `barh` nos dá um gráfico de barras horizontal:

# %%
plt.figure(figsize=(8,3), dpi=150)
plt.barh(continentes.index, continentes['2022 Population'], zorder=2)
plt.xlabel('População em Bilhões')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# #### **Exercício**
# Vamos fazer um gráfico de barras que mostre a porcentagem de população de cada continente.

# %%
# Coloque seu código aqui
plt.figure(figsize=(8,3), dpi=150)
plt.bar(continentes.index, continentes['World Population Percentage'], zorder=2)
plt.ylabel('Porcentagem da População Mundial')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### Histogramas 📊

# %% [markdown]
# Um histograma é um gráfico que agrupa números em intervalos. Estes intervalos são chamados de *bins*. Isso significa que o gráfico mostra **quantos** dados se encaixam em determinada característica.

# %% [markdown]
# #### Bins
# *Bin* é uma palavra do inglês que significa um lugar usado para armazenar, como uma caixa, baú, etc. Então, para nossos histogramas, cada *bin* é uma 'caixa' que guarda os valores que estão dentro de um intervalo (as paredes da caixa). Veja um exemplo:

# %% [markdown]
# Como será que é a distribuição de países com relação ao crescimento populacional? 🤔\
# Essa é uma pergunta que pode ser respondida com um histograma! Podemos criar histogramas com o método `hist()` do matplotlib. Como parâmetros, passamos a coluna queremos que seja contada. Neste caso, queremos que conte os países pela taxa de crescimento (*Growth Rate*):

# %%
plt.figure(figsize=(5,3), dpi=150)
plt.hist(wrld_pop['Growth Rate'], zorder=2)
plt.xlabel('Taxa de Crescimento Populacional')
plt.ylabel('Número de Países')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Beleza! Fizemos nosso gráfico. O que ele nos mostra que a maioria dos países tem uma taxa de crescimento por volta de 1. Mas ele ficou meio estranho, não acha? 🤨 As barras não estão centralizadas, tá meio feio... e ainda por cima ele tá mostrando os valores muito amontoados... Vamos mudar isso. 😉

# %% [markdown]
# Podemos escolher os intervalos dos nossos *bins* passando uma lista pro parâmetro `bins` no método `hist()`. Isso vai mudar também como o nosso eixo $x$ é apresentado na imagem. Vamos escolher alguns novos valores pro eixo $x$.

# %%
plt.figure(figsize=(5,3), dpi=150)
plt.hist(wrld_pop['Growth Rate'], bins=[0.98,0.99,1,1.01,1.02,1.03,1.04,1.05], zorder=2)
plt.xlabel('Taxa de Crescimento Populacional')
plt.ylabel('Número de Países')
plt.grid(axis='y', zorder=0)
plt.show()

# %% [markdown]
# Agora ele está mais legível! Aqui escolhemos mostrar só os países que estão entre 0.98 e 1.05 de taxa de crescimento populacional.

# %% [markdown]
# Bora tentar fazer o mesmo gráfico de taxa de crescimento, mas desta vez só com os países da Europa. Vamos começar criando um novo dataframe que só tenha os países da Europa. Podemos usar o nosso velho amigo `loc` pra isso:

# %%
Europa = wrld_pop.loc[wrld_pop['Continent'] == 'Europe']
Europa.head()
# Out:
#       Rank Country/Territory Capital Continent  2022 Population  \
# CCA3
# RUS      9            Russia  Moscow    Europe        144713314
# DEU     19           Germany  Berlin    Europe         83369843
# GBR     21    United Kingdom  London    Europe         67508936
# FRA     23            France   Paris    Europe         64626628
# ITA     25             Italy    Rome    Europe         59037474
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# CCA3
# RUS         145617329        144668389        143242599        146844839
# DEU          83328988         82073226         81325090         81551677
# GBR          67059474         65224364         62760039         58850043
# FRA          64480053         63809769         62444567         58665453
# ITA          59500579         60232906         59822450         56966397
#
#       1990 Population  1980 Population  1970 Population  Area (km²)  \
# CCA3
# ...

# %% [markdown]
# Agora, só precisamos colocar nosso dataframe no método `hist()`!

# %%
plt.figure(figsize=(5,3), dpi=150)
plt.hist(Europa['Growth Rate'], zorder=2)
plt.xlabel('Taxa de Crescimento Populacional')
plt.ylabel('Número de Países da Europa')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Vamos tentar fazer o eixo $x$ ir de 0.01.

# %%
plt.figure(figsize=(5,3), dpi=150)
plt.hist(Europa['Growth Rate'], bins=[0.98,0.99,1,1.01,1.02,1.03,1.04,1.05], zorder=2)
plt.xlabel('Taxa de Crescimento Populacional')
plt.ylabel('Número de Países da Europa')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# #### **Exercício**
# Crie um histograma que mostre com a taxa de crescimento populacional dos países da África. Dica: siga os passos que fizemos para a Europa!

# %%
## Coloque seu código aqui
Africa = wrld_pop.loc[wrld_pop['Continent'] == 'Africa']

plt.figure(figsize=(5,3), dpi=150)
plt.hist(Africa['Growth Rate'], bins=[0.99,1,1.01,1.02,1.03,1.04,1.05], zorder=2)
plt.xlabel('Taxa de Crescimento Populacional')
plt.ylabel('Número de Países da Africa')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## Método `merge()`

# %% [markdown]
# Existe um método do pandas muito poderoso que serve para juntarmos dois dataframes em um. O `merge()` vai colocar as colunas de um dos dataframes no outro e, se os dois tiverem colunas em comum, elas vão se manter intactas como uma.

# %% [markdown]
# Vamos tentar usar o `merge()` com dois datasets: um que representa o GDP (*Gross domestic product*) de cada país e o nosso dataframe das populações. O GDP é chamado de Produto Interno Bruto (PIB) no Brasil.\
# Enfim, vamos começar lendo o csv do GDP:

# %%
gdp=pd.read_csv('gdp_by_country.csv')
gdp.head()
# Out:
#                  Country    1999    2000    2001    2002    2003    2004  \
# 0  Afghanistan, Rep. of.       0       0       0   4.084   4.585   5.971
# 1                Albania   3.444   3.695   4.096   4.456     5.6   7.452
# 2                Algeria  48.845  54.749  55.181  57.053  68.013  85.016
# 3                 Angola   6.153   9.135   8.936  11.386  13.956    19.8
# 4    Antigua and Barbuda   0.652   0.678    0.71   0.718   0.754   0.818
#
#      2005     2006     2007  ...     2013     2014     2015    2016     2017  \
# 0   7.309    8.399    9.892  ...   21.555   24.304        0       0        0
# 1   8.376    9.133   10.163  ...    14.91   16.053   11.591  12.204   13.214
# 2  102.38  114.322  116.158  ...  190.432  203.449  175.077  181.71  192.256
# 3  30.632   43.759    55.37  ...  136.415  151.089  102.011  98.815  105.369
# 4   0.875    0.962    1.026  ...    1.404    1.494    1.285   1.328    1.386
#
#       2018     2019    2020     2021     2022
# ...

# %% [markdown]
# Antes de tentarmos juntar os dataframes, vamos *dropar* algumas dessas colunas que não vamos usar, já que nosso dataset tá muito grande.

# %%
lista_pra_dropar=['1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2012','2013','2014','2015','2016','2017','2018','2019']
gdp.drop(lista_pra_dropar, inplace=True, axis=1)
gdp.rename(columns={'Country': 'Country/Territory'}, inplace=True)
gdp = gdp.set_index('Country/Territory')
gdp.head()
# Out:
#                          2020     2021     2022
# Country/Territory
# Afghanistan, Rep. of.       0        0        0
# Albania                16.996    16.77   18.012
# Algeria                219.16  163.812  168.195
# Angola                 127.15   70.339   74.953
# Antigua and Barbuda     1.617    1.405    1.534

# %% [markdown]
# Agora tá mais bala. Bora usar o merge! 🤯\
# Dentro do método `merge()`, colocamos o dataframe que queremos juntar e podemos colocar parâmetro `on` ao lado. O valor que damos pro `on` tem que ser uma coluna que os dois dataframes tenham em comum. Assim, os nossos dataframes vão se juntar *nestas* colunas.

# %%
wrld_info = wrld_pop.merge(gdp, on='Country/Territory')

wrld_info.head()
# Out:
#    Rank Country/Territory           Capital      Continent  2022 Population  \
# 0     1             China           Beijing           Asia       1425887337
# 1     2             India         New Delhi           Asia       1417173173
# 2     3     United States  Washington, D.C.  North America        338289857
# 3     4         Indonesia           Jakarta           Asia        275501339
# 4     5          Pakistan         Islamabad           Asia        235824862
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       1424929781       1393715448       1348191368       1264099069
# 1       1396387127       1322866505       1240613620       1059633675
# 2        335942003        324607776        311182845        282398554
# 3        271857970        259091970        244016173        214072421
# 4        227196741        210969298        194454498        154369924
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %% [markdown]
# 😱 Olha as colunas do gdp lá no final! Funcionou perfeitamente! Mas tem um detalhe bem importante nessas colunas: os valores novos possuem **vírgulas**. 😳 Isso não é bom. Vamos ver qual é o tipo de dado dessas colunas.

# %% [markdown]
# ### Método `info()`

# %% [markdown]
# Existe um método para verificarmos qual o tipo de dado que cada coluna possui de forma rápida. Este método é o `info()`, da própria biblioteca pandas:

# %%
wrld_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 0 to 156
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         157 non-null    int64
#  1   Country/Territory            157 non-null    object
#  2   Capital                      157 non-null    object
#  3   Continent                    157 non-null    object
#  4   2022 Population              157 non-null    int64
#  5   2020 Population              157 non-null    int64
#  6   2015 Population              157 non-null    int64
#  7   2010 Population              157 non-null    int64
#  8   2000 Population              157 non-null    int64
#  9   1990 Population              157 non-null    int64
#  10  1980 Population              157 non-null    int64
#  11  1970 Population              157 non-null    int64
#  12  Area (km²)                   157 non-null    int64
# ...

# %% [markdown]
# Olha ali como as colunas 2020, 2021 e 2022 são objetos... 😡 Significa que os dados que estão ali não são *números*, e sim qualquer outra coisa que não é um número 😵. Pra podermos usar esses dados direito, vamos ter que transformar essas informações em tipo *float*.

# %% [markdown]
# Vamos dar uma lembrada na aula de limpeza de dados. Lá, usamos o método `replace()` em múltiplos números ao mesmo tempo. Como o `replace` funciona em strings, a gente coloca o ``.str`` antes pra transformar o objeto da nossa coluna em string.

# %%
wrld_info['2020']=wrld_info['2020'].str.replace(',', '')
wrld_info.head()
# Out:
#    Rank Country/Territory           Capital      Continent  2022 Population  \
# 0     1             China           Beijing           Asia       1425887337
# 1     2             India         New Delhi           Asia       1417173173
# 2     3     United States  Washington, D.C.  North America        338289857
# 3     4         Indonesia           Jakarta           Asia        275501339
# 4     5          Pakistan         Islamabad           Asia        235824862
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       1424929781       1393715448       1348191368       1264099069
# 1       1396387127       1322866505       1240613620       1059633675
# 2        335942003        324607776        311182845        282398554
# 3        271857970        259091970        244016173        214072421
# 4        227196741        210969298        194454498        154369924
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %% [markdown]
# Veja que belezinha! Agora vamos fazer isso pras outras colunas!

# %%
wrld_info['2021']=wrld_info['2021'].str.replace(',', '')
wrld_info['2022']=wrld_info['2022'].str.replace(',', '')
wrld_info.head()
# Out:
#    Rank Country/Territory           Capital      Continent  2022 Population  \
# 0     1             China           Beijing           Asia       1425887337
# 1     2             India         New Delhi           Asia       1417173173
# 2     3     United States  Washington, D.C.  North America        338289857
# 3     4         Indonesia           Jakarta           Asia        275501339
# 4     5          Pakistan         Islamabad           Asia        235824862
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       1424929781       1393715448       1348191368       1264099069
# 1       1396387127       1322866505       1240613620       1059633675
# 2        335942003        324607776        311182845        282398554
# 3        271857970        259091970        244016173        214072421
# 4        227196741        210969298        194454498        154369924
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %% [markdown]
# Perfeito! 😀\
# Mas ainda tem um passo que precisamos fazer. Apesar de termos tirado as vírgulas, os números ali dentro viraram strings. Precisamos transformá-los em floats. Como será que podemos fazer isso? 🤔

# %% [markdown]
# Olha só a tecnologia: existe um método que faz isso pra gente. 🤭🤭

# %% [markdown]
# ### `astype()`
# O pandas possui um método chamado `astype()` que nos permite passar um dicionário. Escolhemos as colunas que queremos como as chaves do dicionário e o tipo de dado como os valores do dicionário. Assim a gente não precisa passar de dado em dado pra transformar em float! Aí fica fácil em! 🥱

# %%
wrld_info=wrld_info.astype({'2020':'float', '2021':'float', '2022':'float'})
wrld_info.head()
# Out:
#    Rank Country/Territory           Capital      Continent  2022 Population  \
# 0     1             China           Beijing           Asia       1425887337
# 1     2             India         New Delhi           Asia       1417173173
# 2     3     United States  Washington, D.C.  North America        338289857
# 3     4         Indonesia           Jakarta           Asia        275501339
# 4     5          Pakistan         Islamabad           Asia        235824862
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       1424929781       1393715448       1348191368       1264099069
# 1       1396387127       1322866505       1240613620       1059633675
# 2        335942003        324607776        311182845        282398554
# 3        271857970        259091970        244016173        214072421
# 4        227196741        210969298        194454498        154369924
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %% [markdown]
# Agora sim está perfeito!

# %% [markdown]
# Agora que arrumamos nosso dataframe, bora tentar usar nossos novos dados pra formar um gráfico.\
# Será que o GDP do Brasil cresceu entre 2020 e 2022??? 🤔🤔 Vamos tentar descobrir com um gráfico de barras.\
# Primeiro, selecionamos o Brasil:

# %%
brasil = wrld_info.loc[wrld_info['Country/Territory'] == 'Brazil']
brasil
# Out:
#    Rank Country/Territory   Capital      Continent  2022 Population  \
# 6     7            Brazil  Brasilia  South America        215313498
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 6        213196304        205188205        196353492        175873720
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 6        150706446        122288383         96369875     8515767
#
#    Density (per km²)  Growth Rate  World Population Percentage     2020  \
# 6            25.2841       1.0046                          2.7  2054.41
#
#       2021     2022
# 6  1645.84  1810.61

# %% [markdown]
# Boa! Agora a gente cria duas listas com *o que* mostraremos no gráfico: uma para o eixo $x$ e outra para o eixo $y$. Lembrando que o eixo $x$ vai mostrar os anos e o $y$ o GDP do Brasil em cada um desses anos.

# %%
anos=[2020,2021,2022]
gdp_brasil = list(brasil.iloc[0,16:19].values)
gdp_brasil
# Out:
# [2054.41, 1645.84, 1810.61]

# %% [markdown]
# Veja que usamos o método `list()` para transformar o conjunto de valores que pegamos do dataframe em uma lista. Selecionamos a partir do `iloc` a linha 0 e as colunas do intervalo 16-19 e pegamos os valores da série que o `iloc` nos retorna.

# %% [markdown]
# Beleza, agora tudo o que precisamos fazemos é colocar as nossas duas listas no método `bar()`. Primeiro a nossa lista do eixo $x$ e depois a lista do eixo $y$. Bora colocar uma corzinha BRASILEIRA no nosso gráfico também! 😁

# %%
plt.figure(figsize=(6,4), dpi=150)
plt.bar(anos, gdp_brasil, color='#009739', zorder=2)
plt.ylabel('GDP do Brasil (milhões de US$)')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Uau, ficou muito bom! Mas tem um detalhe chato ali... tem esses valores não inteiros nos anos, fica meio feio, não acha? Vamos tentar mudar isso.

# %% [markdown]
# Podemos escolher os *ticks* que serão mostrados nos nossos eixos usando os métodos `xticks` e `yticks`. O nosso gráfico em si não vai mudar, só os números que aparecem ali.

# %%
plt.figure(figsize=(6,4), dpi=150)
plt.bar(anos, gdp_brasil, color='#009739', zorder=2)
plt.ylabel('GDP do Brasil (milhões de US$)')
plt.xticks([2020,2021,2022])
plt.yticks([0,500,1000,1500,2000])
plt.grid(axis='y')
plt.show()

# %% [markdown]
# 🤩 Está incrível! Tirando a parte que o GDP do Brasil caiu desde 2020... 😣\
# Enfim, o que importa é o gráfico.

# %% [markdown]
# ## Gráficos Múltiplos com o Dataset

# %% [markdown]
# Agora que exploramos um pouco cada tipo de gráfico e buscamos algumas informações interessantes, vamos voltar ao gráfico de linha.

# %% [markdown]
# Vamos tentar fazer um gráfico de linha que mostre o crescimento populacional de alguns países juntos. Usaremos a lista de países Brasil, Estados Unidos, Indonésia, Paquistão e Coreia do Sul. Vamos fazer o mesmo processo que antes: formar listas com o que queremos.

# %%
eixo_x=[1970,1980,1990,2000,2010,2015,2020,2022]
brasil_pop = list(reversed(brasil.iloc[0,4:12].values))
indo_pop=list(reversed(wrld_pop.loc[wrld_pop['Country/Territory'] == 'Indonesia'].iloc[0,4:12].values))
paq_pop=list(reversed(wrld_pop.loc[wrld_pop['Country/Territory'] == 'Pakistan'].iloc[0,4:12].values))
nig_pop=list(reversed(wrld_pop.loc[wrld_pop['Country/Territory'] == 'Nigeria'].iloc[0,4:12].values))
us_pop=list(reversed(wrld_pop.loc[wrld_pop['Country/Territory'] == 'United States'].iloc[0,4:12].values))

# %%
plt.figure(figsize=(6,4), dpi=150)

plt.plot(eixo_x, brasil_pop, color="#ffcc33", linestyle='--', marker='.', markersize=7, label='Brasil')
plt.plot(eixo_x, indo_pop, color="#f70000", linestyle='--', marker='.', markersize=7, label='Indonésia')
plt.plot(eixo_x, paq_pop, color="#013f1b", linestyle='--', marker='.', markersize=7, label='Paquistão')
plt.plot(eixo_x, nig_pop, color="#009933", linestyle='--', marker='.', markersize=7, label='Nigéria')
plt.plot(eixo_x, us_pop, color="#2b2baa", linestyle='--', marker='.', markersize=7, label='Estados Unidos')
plt.ylabel('População em 100 milhões')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## `value_counts()`

# %% [markdown]
# Quando trabalhamos com um dataset não numérico, é muitas vezes necessário usar outras ferramentas para criarmos nossos gráficos. Nesta mesma aula, coloquei um dataset diferente sobre Pokémon. Este dataset nos traz algumas informações sobre cada pokémon desde a geração 1 até a 6.

# %%
pokemon=pd.read_csv('Pokemon.csv')

# %%
pokemon.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %% [markdown]
# Usando o `.info()`, podemos ver os tipos de cada coluna:

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 749 entries, 0 to 748
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           749 non-null    int64
#  1   Name        749 non-null    object
#  2   Type 1      749 non-null    object
#  3   Type 2      374 non-null    object
#  4   Total       749 non-null    int64
#  5   HP          749 non-null    int64
#  6   Attack      749 non-null    int64
#  7   Defense     749 non-null    int64
#  8   Sp. Atk     749 non-null    int64
#  9   Sp. Def     749 non-null    int64
#  10  Speed       749 non-null    int64
#  11  Generation  749 non-null    int64
#  12  Legendary   749 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 71.1+ KB

# %% [markdown]
# Como podemos perceber, temos diversas colunas que carregam dados de tipos não numéricos. Suponha que a gente queira criar um gráfico de barras que mostre o número de Pokémon que cada tipo possui. Não podemos simplesmente colocar nosso dataset no método `bar()` porque os dados de tipos não são numéricos... O que podemos fazer, então?
# Podemos usar o método `value_counts()`, que vimos algumas aulas atrás para contar o número de aparições de cada dado!

# %%
type1pkm=pokemon['Type 1'].value_counts()
type(type1pkm)
# Out:
# pandas.core.series.Series

# %%
type1pkm
# Out:
# Water       106
# Normal       94
# Grass        66
# Bug          65
# Psychic      52
# Fire         48
# Electric     42
# Rock         41
# Ground       31
# Ghost        30
# Poison       28
# Dark         28
# Dragon       26
# Fighting     25
# Ice          23
# Steel        23
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# O `value_counts()` nos retorna uma série. Então, para acessar apenas os valores da nossa série, selecionamos apenas os atributos *values*. Para a lista de nomes dos tipos, selecionamos o atributo *index* da série, porque na série que o `value_counts()` nos retorna, o índice carrega os nomes.

# %%
plt.figure(figsize=(15,4), dpi=300)

plt.bar(type1pkm.index, type1pkm.values, zorder=2)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# É claro, este gráfico que fizemos considera apenas o tipo 1 dos Pokémon. E se quisermos adicionar os Pokémon do tipo 2 na contagem também? 🧐

# %% [markdown]
# Podemos começar seguindo o mesmo método de `value_counts`, desta vez com a coluna 'Type 2':

# %%
type2pkm=pokemon['Type 2'].value_counts()
type2pkm.head()
# Out:
# Flying     91
# Poison     31
# Ground     31
# Psychic    28
# Grass      25
# Name: Type 2, dtype: int64

# %% [markdown]
# #### `add()`

# %% [markdown]
# Beleza! Temos duas séries, uma com a contagem dos Pokémon e seus tipos primários e outra com os seus tipos secundários. E agora? Precisamos de só uma série para podermos *plotar*! 😓\
# Mais uma vez, temos um método para nos salvar! O `add()` vai somar os valores das duas séries quando o índice deles coincidirem, o que é exatamente o que queremos!

# %%
alltypepkm=type1pkm.add(type2pkm)
alltypepkm
# Out:
# Bug          68
# Dark         45
# Dragon       41
# Electric     48
# Fairy        35
# Fighting     46
# Fire         58
# Flying       95
# Ghost        43
# Grass        91
# Ground       62
# Ice          36
# Normal       98
# Poison       59
# Psychic      80
# Rock         55
# Steel        43
# Water       120
# dtype: int64

# %% [markdown]
# *Plotando* nós obtemos:

# %%
plt.figure(figsize=(15,6), dpi=300)

plt.bar(alltypepkm.index, alltypepkm.values, zorder=2)
plt.grid(axis = 'y')

plt.show()

# %% [markdown]
# Veja que belo gráfico! 🤗

# %% [markdown]
# Usando essas mesmas propriedades, podemos fazer um gráfico de pizza que mostra a porcentagem de Pokémon que são lendários e quantos não:

# %%
plt.figure(figsize=(4,3), dpi=150)

plt.pie(pokemon['Legendary'].value_counts().values, labels=pokemon['Legendary'].value_counts().index, autopct='%.2f%%', labeldistance=1.15)

plt.show()

# %% [markdown]
# ## Exercícios

# %% [markdown]
# 1. Crie um gráfico do tipo **histograma** que mostre o intervalo em que a maioria dos Pokémon tem seus atributos totais (coluna Total do dataset).

# %%
# Selecionar os valores máximos da coluna total
max_total = pokemon['Total'].max()

# Criar o histograma
plt.figure(figsize=(6,4), dpi=150)
plt.hist(pokemon['Total'], bins=range(0, max_total, 50), color='#009739', zorder=2)
plt.xlabel('Total')
plt.ylabel('Quantidade')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# 2. Crie um gráfico do tipo **linha** que mostre os lançamentos de novos Pokémon em cada geração (coluna Generation no dataset). Dica: tente ordenar a série pelo índice com `sort_index()` antes de *plotar* no gráfico!

# %%
# parte 1: criar a série
generation = pokemon['Generation'].value_counts().sort_index()

# parte 2: plotar o gráfico
plt.figure(figsize=(6,4), dpi=150)
plt.plot(generation.index, generation.values, color='#009739', zorder=2, marker='.', markersize=7)

# parte 3: adicionar título e rótulos aos eixos
plt.title('Quantidade de lançamentos por geração')
plt.xlabel('Geração')
plt.ylabel('Quantidade')

# parte 4: adicionar grade
plt.grid()

# parte 5: mostrar o gráfico
plt.show()

# %% [markdown]
# 3. Crie um novo dataframe que agrupa os Pokemón pela geração e que calcule as médias de cada atributo numérico. Em seguida, crie um gráfico do tipo linha que mostre a média de atributos totais de cada geração.

# %%
# parte 1: agrupar os por geração
drop_non_numeric = pokemon.drop(['#', 'Name', 'Type 1', 'Type 2', 'Legendary'], axis=1)
pokemon_by_generation = drop_non_numeric.groupby('Generation').mean()

# parte 2: plotar o gráfico
plt.figure(figsize=(6,4), dpi=150)
plt.plot(pokemon_by_generation.index, pokemon_by_generation['Total'], color='#009739', zorder=2, marker='.', markersize=7)

# parte 3: adicionar título e rótulos aos eixos
plt.title('Média de atributos totais por geração')
plt.xlabel('Geração')
plt.ylabel('Média de atributos totais')

# parte 4: adicionar grade
plt.grid()

# parte 5: mostrar o gráfico
plt.show()

# %% [markdown]
# 4. Mostre os atributos do pokémon Corphish no modo de barra. Dica: selecione o pokémon com o método `loc` e depois selecione colunas HP, Attack, Defense, Sp. Atk, Sp. Def e Speed com ``iloc`` (os índices dessas colunas são 5, 6, 7, 8, 9 e 10 no dataset).

# %%
# parte 1: selecionar o pokémon
corphish = pokemon.loc[pokemon['Name'] == 'Corphish']

# parte 2: selecionar os atributos
corphish_attributes = corphish.iloc[:, 5:11]

# parte 3: plotar o gráfico
plt.figure(figsize=(6,4), dpi=150)
plt.bar(corphish_attributes.columns, corphish_attributes.values[0], color='#009739', zorder=2)

# parte 4: adicionar título e rótulos aos eixos
plt.title('Atributos do Corphish')
plt.xlabel('Atributo')
plt.ylabel('Valor')

# parte 5: adicionar grade
plt.grid(axis='y')

# parte 6: mostrar o gráfico
plt.show()
